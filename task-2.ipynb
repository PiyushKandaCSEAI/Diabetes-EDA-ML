# %%
df <- read.csv("/content/filtered_diabetes_data.csv")
head(df)
# Out:
#   Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# 1 6           148     72            35            125     33.6
# 2 1            85     66            29            125     26.6
# 3 8           183     64            29            125     23.3
# 4 1            89     66            23             94     28.1
# 5 0           137     40            35            168     43.1
# 6 5           116     74            29            125     25.6
#   DiabetesPedigreeFunction Age Outcome
# 1 0.627                    50  1
# 2 0.351                    31  0
# 3 0.672                    32  1
# 4 0.167                    21  0
# 5 2.288                    33  1
# 6 0.201                    30  0

# %% [markdown]
# **histograms**

# %%
ggplot(data = df, aes(x = Pregnancies)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of Pregnancies") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = Glucose)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of Pregnancies") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = BloodPressure)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of Blood Pressure") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = SkinThickness)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of SkinThickness") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = BloodPressure)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of BloodPressure") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = Insulin)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of Insulin") + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = BMI)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = 'Distribution of DiabetesPedigreeFunction') + theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = Age)) + geom_histogram(binwidth = 1, fill = 'skyblue', color = 'black') + labs(title = "Distribution of Age") + theme_minimal()
# Out:
# plot without title
